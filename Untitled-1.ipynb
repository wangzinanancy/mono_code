# %% [markdown]
# Requirement
# Use Python or JavaScript to print:
# 1. the user name of all the weddings that take place in 2024 june
# 2. the user name of all the wedding will happen in 2 weeks
# All the information is provided in the CSV attached. you can fork this repo to start the challenge.
#
# Your need to follow these rules:
# 1. use a DB (pandas or similar package is not accepted)
# 2. save the output in the file
# 3. your code should be testable on any platform (windows/linux/macos)
# 4. commit message/ readme/ unit test is also part of the test.

# %%
import sqlite3
print(sqlite3.sqlite_version)
# Out:
# 3.40.1

# %%
from datetime import datetime, timedelta
import csv

# %%
# 创建和连接到 SQLite 数据库
conn = sqlite3.connect('weddings.db')
cursor = conn.cursor()

# %%
# 读取 CSV 文件
with open('Users_Data.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    next(reader)  # 跳过标题行
    for row in reader:
        user_id, user_name = row[0], row[1]
        print(f"user_id: {user_id}, user_name: {user_name}")
# Out:
# user_id: 11c602f2-5541-453b-a3e1-dec9b6a273c3, user_name: David Anderson
# user_id: 58b3a3b5-f2d8-434b-afff-d0c4d977f081, user_name: Jane Miller
# user_id: ab9f9165-57f6-4306-9a1f-9ebbc70d2400, user_name: Grace Taylor
# user_id: d6ff2fd4-6cb6-4b39-b8dc-df46d3c16fa7, user_name: Laura Harris
# user_id: e940346b-bbfc-4f06-a94d-1adf4e558360, user_name: Emma Garcia
# user_id: 3f2c0120-82a1-49eb-91c6-ecb5d0ffc581, user_name: David White
# user_id: f89b5aee-d073-4cec-99c6-2e0f26513833, user_name: Brian Anderson
# user_id: 151d61f3-6900-447b-94cf-c904bc1025f2, user_name: Michael Johnson
# user_id: 60407612-4daf-4065-8cb2-31e540a6abea, user_name: Emma Thomas
# user_id: 9f8b8de2-4517-4797-ad73-63fde4f1e6e8, user_name: Brian Thompson
# user_id: 13307de0-c96a-4841-83d3-c6b1fe093e14, user_name: Hannah Davis
# user_id: ef10e49b-6149-4341-8335-e16f96728fed, user_name: Alex Smith
# user_id: 9b8ec470-5429-4c59-9b78-c6d7d7256ae8, user_name: Robert Robinson
# user_id: c679f8b3-9aa2-44c2-942d-80e5765d44c0, user_name: John Smith
# user_id: 6d3ee316-194b-4a0b-aefb-6367d8ef005c, user_name: Grace Wilson
# user_id: ce794db8-2777-4865-b409-d6b171f43162, user_name: Katie Smith
# user_id: b730dffe-242d-4e3d-b107-4a10827100ee, user_name: Robert Williams
# user_id: b62bdde6-593f-4d2d-8320-29c343705545, user_name: Laura Moore
# user_id: abd124e9-ad07-4575-b847-aba813580e86, user_name: Brian Brown
# user_id: 6b30fba9-0ed3-46e1-979f-cbb21263a653, user_name: Kevin Davis
# user_id: d3d669f0-ba28-4fdb-b11c-7a4b7b28dde6, user_name: Emily Martin
# user_id: ac843fe1-87ef-42aa-a379-c4a6c8a547ce, user_name: Emily Taylor
# user_id: 1b66ecec-cbf3-4b8a-8c91-07fb04f53331, user_name: Jane Taylor
# user_id: 48fd430f-169f-4549-a1ff-f61810b2aee1, user_name: Alex Wilson
# user_id: 7d41d6d6-b0ef-42b7-98ac-bbeda2a4e01b, user_name: Katie Johnson
# user_id: 6b2e596e-9932-450f-92c5-b46f1d3a151c, user_name: Olivia Johnson
# user_id: cdfccb3a-1e9a-4c11-a2df-78f3db1ab509, user_name: James Wilson
# user_id: ee4c7261-a59e-4656-a63b-767030da3017, user_name: Sophia Miller
# user_id: 8866ae0b-0e44-4ff7-8efb-73a2a333c578, user_name: Laura Thomas
# user_id: ca735fed-49cf-4525-b448-3bdaf1db0f45, user_name: Brian Robinson
# user_id: a0bc75af-8566-49e2-860e-e26656840ca1, user_name: Brian Moore
# user_id: f3441ef8-67ec-49b6-a251-914333796e49, user_name: Sarah Taylor
# user_id: 2da092e9-d53f-45e4-afeb-b6cf785f5074, user_name: Brian Brown
# user_id: e71bcd4b-6166-4d72-9f9a-2ea9bca46fd5, user_name: Katie Wilson
# user_id: 564a4663-3989-4ec2-90e3-f415458562e2, user_name: Sarah Martinez
# user_id: ea1333bc-b598-445e-b497-ae34e7f08d98, user_name: Emma Williams
# user_id: c3ab9534-5cec-4087-883e-9e1a684334f6, user_name: Sophia Jackson
# user_id: 6c094d08-f451-4e09-b2f7-d47719c55db2, user_name: John Wilson
# user_id: 2d5684e7-5777-4ca8-b2d6-ce86c1430651, user_name: Hannah Johnson
# user_id: b6d48fa8-4c7a-447a-92c3-83183322b02b, user_name: Kevin Anderson
# user_id: 225b2c59-4b16-46c8-887e-844cad35eb03, user_name: David Moore
# user_id: 8a975c7e-4553-4470-806a-08d819e12f7c, user_name: Emma Wilson
# user_id: 23747f8d-723e-4fb9-9ab0-ffa0788406bd, user_name: Emma Anderson
# user_id: 4e19e7d6-98c5-4bdf-a65b-54454a561e8e, user_name: John Harris
# user_id: 147a2b22-0458-450c-b89a-bba8f380bc12, user_name: Chris Thomas
# user_id: 641127ff-1c57-47b0-acca-9dbbe91763f6, user_name: Sophia Williams
# user_id: 90c628d9-8c0b-47ae-b744-a71b0446af8e, user_name: Hannah Anderson
# user_id: 604a24cb-6055-4661-96c5-22c5d4b0224a, user_name: Emma Anderson
# user_id: 066e6611-13f2-4c20-af25-890c64b95042, user_name: Brian Davis
# user_id: 0c8a57f0-40c3-4dc4-9966-5c656d7b8363, user_name: Hannah Taylor
# user_id: 0c810a97-1bea-4ffd-82d8-3a433092099a, user_name: Katie Jackson
# user_id: 6439b84f-2873-4e18-bb03-7b95a5398318, user_name: Michael Williams
# user_id: bfa0e361-c55d-4d3b-9e80-1552f4f0294f, user_name: Robert Wilson
# user_id: 3fb95b0e-748f-4335-b3c5-d41a0abf1c7e, user_name: Sophia Wilson
# user_id: 4b779722-5d30-40b5-94a4-0d1d8111f0b5, user_name: Brian Martinez
# user_id: cfd4aaba-9a1c-4b08-88d2-89c8f3293995, user_name: Jane Martinez
# user_id: ea2e7447-f2b0-4911-9ff7-3c9c70459fef, user_name: Laura Brown
# user_id: 019c8dcd-a16d-40c1-a7a1-9e60cd013763, user_name: James Brown
# user_id: 3457a9e3-0eb9-4df4-af2a-10dce4ec2363, user_name: John Harris
# user_id: 9428e9ef-6784-41eb-a92b-31cb982fdfa6, user_name: John Miller
# user_id: 3e6cdd61-b98d-4c89-941d-a4172f0ddc95, user_name: Alex White
# user_id: 3abd2ff5-f920-4fe4-b34b-3d63cefb6be3, user_name: Olivia Martin
# user_id: baf8fbbe-14f4-4379-b2d2-724c15a792d3, user_name: Sarah Robinson
# user_id: dd2cc75d-1e6a-40d4-ad90-e0343236133b, user_name: Chris Johnson
# user_id: 27e9b19d-4f1e-48eb-b9a0-daed430f111a, user_name: Olivia Thomas
# user_id: 628b7cc3-e797-4d53-9ee8-b1816a873a8c, user_name: Alex Jackson
# user_id: 726fa289-8cdf-48bf-8b08-1e92a2f0de16, user_name: Michael Thomas
# user_id: ecb8d252-0adc-4e67-9133-2c9274d5547e, user_name: Emily Davis
# user_id: 18085e3f-a081-4aa5-988c-b4213fb1984b, user_name: Michael Harris
# user_id: e25a71bb-1fe8-4702-b2eb-ac17c3db5c45, user_name: Robert Martin
# user_id: a61ecfc0-85ff-4b4f-a317-3a333d09d863, user_name: David Moore
# user_id: 60ab2c22-2555-411c-be8a-78415c570689, user_name: Jane Moore
# user_id: 4bdfcb78-fede-4a25-9bbe-423d199a9377, user_name: Kevin Jones
# user_id: 92b7d0f9-8e68-44c1-a8c1-1acb28599b07, user_name: Katie Johnson
# user_id: e8c5015b-06db-4e16-bc48-a811dde62ee0, user_name: Katie Martin
# user_id: 9742af7f-c77f-4ebd-b7e2-40d6e8f65f83, user_name: Sophia Smith
# user_id: 70b72b51-3d12-4673-8df1-96556bd38fc6, user_name: Michael Brown
# user_id: 0640ac0c-ae21-4f62-886c-36d4172dd561, user_name: John White
# user_id: ac9436ae-5ddf-4f5f-8863-28310c97e463, user_name: Jane White
# user_id: edf172c5-29d2-44a0-8adb-21008f64d571, user_name: Brian Brown
# user_id: ef9a71e4-4e89-49c0-8e8b-e9d207a746df, user_name: Chris Martin
# user_id: b6260fcf-aeab-49f5-bc6a-3f35bf84e04c, user_name: Daniel Jones
# user_id: bbacab2d-ee83-455b-b8c9-8bc05e660c9c, user_name: Laura Robinson
# user_id: 8a35e415-9045-4c8b-9fc3-ec698857d28f, user_name: Chris Jones
# user_id: 78788bd9-4957-419c-abe3-c64bedca0740, user_name: Emma Jones
# user_id: 94809e42-b880-49dc-9a26-da5d8b449acb, user_name: James Jones
# user_id: e75fac0b-96d6-412b-b06e-18abfc85ac30, user_name: Emma Jones
# user_id: 8791463e-d128-4a06-bce5-2902ba9cc8a8, user_name: Michael Williams
# user_id: 708ed8da-3e7c-4972-895b-df0a82ae03c0, user_name: David Williams
# user_id: 48ac894f-b738-468f-b4f6-3e6378c08e38, user_name: Sophia Moore
# user_id: 17e7f629-cdc6-4ab5-bb20-be056f53d6a0, user_name: Olivia Garcia
# user_id: d43177a2-7eb1-4f3e-aa72-412205f3f67a, user_name: Laura Davis
# user_id: 4e41459a-0a26-4ea6-9be9-4bc6ffff61c3, user_name: John Martin
# user_id: 8aa33b9b-d9b6-4e5d-82cd-d158dafafdb4, user_name: James Harris
# user_id: 879f8980-60d7-4188-bed9-422eb8663271, user_name: Alex Johnson
# user_id: c6a646d2-3211-468f-abc6-dac12ad22adc, user_name: Katie Thompson
# user_id: 1ca873c1-b351-4c75-bf23-bd8f1515a47e, user_name: Chris Martinez
# user_id: e297e8e4-2f4d-4f20-a406-cfdb8ecb5d6c, user_name: Daniel White
# user_id: b0c7bcf9-5e87-46a2-ad8b-29216d844e33, user_name: Daniel Thomas
# user_id: 0459e5b7-936c-447a-aad6-690072f5ecc5, user_name: Robert Thompson

# %%
with open('Weddings_Data.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
# user_id: c6a646d2-3211-468f-abc6-dac12ad22adc, wedding_date: 2025-05-24
# user_id: 1ca873c1-b351-4c75-bf23-bd8f1515a47e, wedding_date: 2025-07-04
# user_id: e297e8e4-2f4d-4f20-a406-cfdb8ecb5d6c, wedding_date: 2024-03-25
# user_id: b0c7bcf9-5e87-46a2-ad8b-29216d844e33, wedding_date: 2024-06-06
# user_id: 0459e5b7-936c-447a-aad6-690072f5ecc5, wedding_date: 2024-11-30

# %%
import os

# 删除现有数据库文件
if os.path.exists('weddings.db'):
    os.remove('weddings.db')

# 创建或连接到 SQLite 数据库
conn = sqlite3.connect('weddings.db')
cursor = conn.cursor()

# %%
# 创建 Users 表
cursor.execute('''
CREATE TABLE IF NOT EXISTS Users (
    user_id TEXT PRIMARY KEY,
    user_name TEXT NOT NULL UNIQUE
)
''')


# 从 Users_Data.csv 中读取数据并插入到 Users 表中
with open('Users_Data.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    next(reader)  # 跳过标题行
    for row in reader:
        user_id, user_name = row[0].strip(), row[1].strip()  # 去除空格
        print(f"Processing user: user_id={user_id}, user_name={user_name}")  # 调试信息

        # 检查 user_name 是否已经存在
        cursor.execute('SELECT 1 FROM Users WHERE user_name = ?', (user_name,))
        if cursor.fetchone() is None:
            cursor.execute('INSERT INTO Users (user_id, user_name) VALUES (?, ?)', (user_id, user_name))
        else:
            print(f"Skipped insertion for user_name={user_name} due to UNIQUE constraint")
# Out:
# Processing user: user_id=11c602f2-5541-453b-a3e1-dec9b6a273c3, user_name=David Anderson
# Processing user: user_id=58b3a3b5-f2d8-434b-afff-d0c4d977f081, user_name=Jane Miller
# Processing user: user_id=ab9f9165-57f6-4306-9a1f-9ebbc70d2400, user_name=Grace Taylor
# Processing user: user_id=d6ff2fd4-6cb6-4b39-b8dc-df46d3c16fa7, user_name=Laura Harris
# Processing user: user_id=e940346b-bbfc-4f06-a94d-1adf4e558360, user_name=Emma Garcia
# Processing user: user_id=3f2c0120-82a1-49eb-91c6-ecb5d0ffc581, user_name=David White
# Processing user: user_id=f89b5aee-d073-4cec-99c6-2e0f26513833, user_name=Brian Anderson
# Processing user: user_id=151d61f3-6900-447b-94cf-c904bc1025f2, user_name=Michael Johnson
# Processing user: user_id=60407612-4daf-4065-8cb2-31e540a6abea, user_name=Emma Thomas
# Processing user: user_id=9f8b8de2-4517-4797-ad73-63fde4f1e6e8, user_name=Brian Thompson
# Processing user: user_id=13307de0-c96a-4841-83d3-c6b1fe093e14, user_name=Hannah Davis
# Processing user: user_id=ef10e49b-6149-4341-8335-e16f96728fed, user_name=Alex Smith
# Processing user: user_id=9b8ec470-5429-4c59-9b78-c6d7d7256ae8, user_name=Robert Robinson
# Processing user: user_id=c679f8b3-9aa2-44c2-942d-80e5765d44c0, user_name=John Smith
# Processing user: user_id=6d3ee316-194b-4a0b-aefb-6367d8ef005c, user_name=Grace Wilson
# Processing user: user_id=ce794db8-2777-4865-b409-d6b171f43162, user_name=Katie Smith
# Processing user: user_id=b730dffe-242d-4e3d-b107-4a10827100ee, user_name=Robert Williams
# Processing user: user_id=b62bdde6-593f-4d2d-8320-29c343705545, user_name=Laura Moore
# Processing user: user_id=abd124e9-ad07-4575-b847-aba813580e86, user_name=Brian Brown
# Processing user: user_id=6b30fba9-0ed3-46e1-979f-cbb21263a653, user_name=Kevin Davis
# Processing user: user_id=d3d669f0-ba28-4fdb-b11c-7a4b7b28dde6, user_name=Emily Martin
# Processing user: user_id=ac843fe1-87ef-42aa-a379-c4a6c8a547ce, user_name=Emily Taylor
# Processing user: user_id=1b66ecec-cbf3-4b8a-8c91-07fb04f53331, user_name=Jane Taylor
# Processing user: user_id=48fd430f-169f-4549-a1ff-f61810b2aee1, user_name=Alex Wilson
# Processing user: user_id=7d41d6d6-b0ef-42b7-98ac-bbeda2a4e01b, user_name=Katie Johnson
# Processing user: user_id=6b2e596e-9932-450f-92c5-b46f1d3a151c, user_name=Olivia Johnson
# Processing user: user_id=cdfccb3a-1e9a-4c11-a2df-78f3db1ab509, user_name=James Wilson
# Processing user: user_id=ee4c7261-a59e-4656-a63b-767030da3017, user_name=Sophia Miller
# Processing user: user_id=8866ae0b-0e44-4ff7-8efb-73a2a333c578, user_name=Laura Thomas
# Processing user: user_id=ca735fed-49cf-4525-b448-3bdaf1db0f45, user_name=Brian Robinson
# Processing user: user_id=a0bc75af-8566-49e2-860e-e26656840ca1, user_name=Brian Moore
# Processing user: user_id=f3441ef8-67ec-49b6-a251-914333796e49, user_name=Sarah Taylor
# Processing user: user_id=2da092e9-d53f-45e4-afeb-b6cf785f5074, user_name=Brian Brown
# Skipped insertion for user_name=Brian Brown due to UNIQUE constraint
# Processing user: user_id=e71bcd4b-6166-4d72-9f9a-2ea9bca46fd5, user_name=Katie Wilson
# Processing user: user_id=564a4663-3989-4ec2-90e3-f415458562e2, user_name=Sarah Martinez
# Processing user: user_id=ea1333bc-b598-445e-b497-ae34e7f08d98, user_name=Emma Williams
# Processing user: user_id=c3ab9534-5cec-4087-883e-9e1a684334f6, user_name=Sophia Jackson
# Processing user: user_id=6c094d08-f451-4e09-b2f7-d47719c55db2, user_name=John Wilson
# Processing user: user_id=2d5684e7-5777-4ca8-b2d6-ce86c1430651, user_name=Hannah Johnson
# Processing user: user_id=b6d48fa8-4c7a-447a-92c3-83183322b02b, user_name=Kevin Anderson
# Processing user: user_id=225b2c59-4b16-46c8-887e-844cad35eb03, user_name=David Moore
# Processing user: user_id=8a975c7e-4553-4470-806a-08d819e12f7c, user_name=Emma Wilson
# Processing user: user_id=23747f8d-723e-4fb9-9ab0-ffa0788406bd, user_name=Emma Anderson
# Processing user: user_id=4e19e7d6-98c5-4bdf-a65b-54454a561e8e, user_name=John Harris
# Processing user: user_id=147a2b22-0458-450c-b89a-bba8f380bc12, user_name=Chris Thomas
# Processing user: user_id=641127ff-1c57-47b0-acca-9dbbe91763f6, user_name=Sophia Williams
# Processing user: user_id=90c628d9-8c0b-47ae-b744-a71b0446af8e, user_name=Hannah Anderson
# Processing user: user_id=604a24cb-6055-4661-96c5-22c5d4b0224a, user_name=Emma Anderson
# Skipped insertion for user_name=Emma Anderson due to UNIQUE constraint
# Processing user: user_id=066e6611-13f2-4c20-af25-890c64b95042, user_name=Brian Davis
# Processing user: user_id=0c8a57f0-40c3-4dc4-9966-5c656d7b8363, user_name=Hannah Taylor
# Processing user: user_id=0c810a97-1bea-4ffd-82d8-3a433092099a, user_name=Katie Jackson
# Processing user: user_id=6439b84f-2873-4e18-bb03-7b95a5398318, user_name=Michael Williams
# Processing user: user_id=bfa0e361-c55d-4d3b-9e80-1552f4f0294f, user_name=Robert Wilson
# Processing user: user_id=3fb95b0e-748f-4335-b3c5-d41a0abf1c7e, user_name=Sophia Wilson
# Processing user: user_id=4b779722-5d30-40b5-94a4-0d1d8111f0b5, user_name=Brian Martinez
# Processing user: user_id=cfd4aaba-9a1c-4b08-88d2-89c8f3293995, user_name=Jane Martinez
# Processing user: user_id=ea2e7447-f2b0-4911-9ff7-3c9c70459fef, user_name=Laura Brown
# Processing user: user_id=019c8dcd-a16d-40c1-a7a1-9e60cd013763, user_name=James Brown
# Processing user: user_id=3457a9e3-0eb9-4df4-af2a-10dce4ec2363, user_name=John Harris
# Skipped insertion for user_name=John Harris due to UNIQUE constraint
# Processing user: user_id=9428e9ef-6784-41eb-a92b-31cb982fdfa6, user_name=John Miller
# Processing user: user_id=3e6cdd61-b98d-4c89-941d-a4172f0ddc95, user_name=Alex White
# Processing user: user_id=3abd2ff5-f920-4fe4-b34b-3d63cefb6be3, user_name=Olivia Martin
# Processing user: user_id=baf8fbbe-14f4-4379-b2d2-724c15a792d3, user_name=Sarah Robinson
# Processing user: user_id=dd2cc75d-1e6a-40d4-ad90-e0343236133b, user_name=Chris Johnson
# Processing user: user_id=27e9b19d-4f1e-48eb-b9a0-daed430f111a, user_name=Olivia Thomas
# Processing user: user_id=628b7cc3-e797-4d53-9ee8-b1816a873a8c, user_name=Alex Jackson
# Processing user: user_id=726fa289-8cdf-48bf-8b08-1e92a2f0de16, user_name=Michael Thomas
# Processing user: user_id=ecb8d252-0adc-4e67-9133-2c9274d5547e, user_name=Emily Davis
# Processing user: user_id=18085e3f-a081-4aa5-988c-b4213fb1984b, user_name=Michael Harris
# Processing user: user_id=e25a71bb-1fe8-4702-b2eb-ac17c3db5c45, user_name=Robert Martin
# Processing user: user_id=a61ecfc0-85ff-4b4f-a317-3a333d09d863, user_name=David Moore
# Skipped insertion for user_name=David Moore due to UNIQUE constraint
# Processing user: user_id=60ab2c22-2555-411c-be8a-78415c570689, user_name=Jane Moore
# Processing user: user_id=4bdfcb78-fede-4a25-9bbe-423d199a9377, user_name=Kevin Jones
# Processing user: user_id=92b7d0f9-8e68-44c1-a8c1-1acb28599b07, user_name=Katie Johnson
# Skipped insertion for user_name=Katie Johnson due to UNIQUE constraint
# Processing user: user_id=e8c5015b-06db-4e16-bc48-a811dde62ee0, user_name=Katie Martin
# Processing user: user_id=9742af7f-c77f-4ebd-b7e2-40d6e8f65f83, user_name=Sophia Smith
# Processing user: user_id=70b72b51-3d12-4673-8df1-96556bd38fc6, user_name=Michael Brown
# Processing user: user_id=0640ac0c-ae21-4f62-886c-36d4172dd561, user_name=John White
# Processing user: user_id=ac9436ae-5ddf-4f5f-8863-28310c97e463, user_name=Jane White
# Processing user: user_id=edf172c5-29d2-44a0-8adb-21008f64d571, user_name=Brian Brown
# Skipped insertion for user_name=Brian Brown due to UNIQUE constraint
# Processing user: user_id=ef9a71e4-4e89-49c0-8e8b-e9d207a746df, user_name=Chris Martin
# Processing user: user_id=b6260fcf-aeab-49f5-bc6a-3f35bf84e04c, user_name=Daniel Jones
# Processing user: user_id=bbacab2d-ee83-455b-b8c9-8bc05e660c9c, user_name=Laura Robinson
# Processing user: user_id=8a35e415-9045-4c8b-9fc3-ec698857d28f, user_name=Chris Jones
# Processing user: user_id=78788bd9-4957-419c-abe3-c64bedca0740, user_name=Emma Jones
# Processing user: user_id=94809e42-b880-49dc-9a26-da5d8b449acb, user_name=James Jones
# Processing user: user_id=e75fac0b-96d6-412b-b06e-18abfc85ac30, user_name=Emma Jones
# Skipped insertion for user_name=Emma Jones due to UNIQUE constraint
# Processing user: user_id=8791463e-d128-4a06-bce5-2902ba9cc8a8, user_name=Michael Williams
# Skipped insertion for user_name=Michael Williams due to UNIQUE constraint
# Processing user: user_id=708ed8da-3e7c-4972-895b-df0a82ae03c0, user_name=David Williams
# Processing user: user_id=48ac894f-b738-468f-b4f6-3e6378c08e38, user_name=Sophia Moore
# Processing user: user_id=17e7f629-cdc6-4ab5-bb20-be056f53d6a0, user_name=Olivia Garcia
# Processing user: user_id=d43177a2-7eb1-4f3e-aa72-412205f3f67a, user_name=Laura Davis
# Processing user: user_id=4e41459a-0a26-4ea6-9be9-4bc6ffff61c3, user_name=John Martin
# Processing user: user_id=8aa33b9b-d9b6-4e5d-82cd-d158dafafdb4, user_name=James Harris
# Processing user: user_id=879f8980-60d7-4188-bed9-422eb8663271, user_name=Alex Johnson
# Processing user: user_id=c6a646d2-3211-468f-abc6-dac12ad22adc, user_name=Katie Thompson
# Processing user: user_id=1ca873c1-b351-4c75-bf23-bd8f1515a47e, user_name=Chris Martinez
# Processing user: user_id=e297e8e4-2f4d-4f20-a406-cfdb8ecb5d6c, user_name=Daniel White
# Processing user: user_id=b0c7bcf9-5e87-46a2-ad8b-29216d844e33, user_name=Daniel Thomas
# Processing user: user_id=0459e5b7-936c-447a-aad6-690072f5ecc5, user_name=Robert Thompson

# %%
# 创建 Weddings 表，确保 user_id 是 TEXT 类型
cursor.execute('''
CREATE TABLE IF NOT EXISTS Weddings (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    user_id TEXT NOT NULL,
    wedding_date DATE NOT NULL,
    FOREIGN KEY (user_id) REFERENCES Users (user_id)
)
''')

# 从 Weddings_Data.csv 中读取数据并插入到 Weddings 表中
with open('Weddings_Data.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    next(reader)  # 跳过标题行
    for row in reader:
        user_id, wedding_date = row[0].strip(), row[1].strip()  # 去除空格
        print(f"Inserting into Weddings: user_id={user_id}, wedding_date={wedding_date}")  # 调试信息
        cursor.execute('INSERT INTO Weddings (user_id, wedding_date) VALUES (?, ?)', (user_id, wedding_date))

conn.commit()
# Out:
# Inserting into Weddings: user_id=11c602f2-5541-453b-a3e1-dec9b6a273c3, wedding_date=2024-08-16
# Inserting into Weddings: user_id=58b3a3b5-f2d8-434b-afff-d0c4d977f081, wedding_date=2024-07-07
# Inserting into Weddings: user_id=ab9f9165-57f6-4306-9a1f-9ebbc70d2400, wedding_date=2024-07-25
# Inserting into Weddings: user_id=d6ff2fd4-6cb6-4b39-b8dc-df46d3c16fa7, wedding_date=2024-11-30
# Inserting into Weddings: user_id=e940346b-bbfc-4f06-a94d-1adf4e558360, wedding_date=2024-01-18
# Inserting into Weddings: user_id=3f2c0120-82a1-49eb-91c6-ecb5d0ffc581, wedding_date=2025-01-04
# Inserting into Weddings: user_id=f89b5aee-d073-4cec-99c6-2e0f26513833, wedding_date=2025-09-24
# Inserting into Weddings: user_id=151d61f3-6900-447b-94cf-c904bc1025f2, wedding_date=2024-05-12
# Inserting into Weddings: user_id=60407612-4daf-4065-8cb2-31e540a6abea, wedding_date=2024-12-02
# Inserting into Weddings: user_id=9f8b8de2-4517-4797-ad73-63fde4f1e6e8, wedding_date=2025-02-27
# Inserting into Weddings: user_id=13307de0-c96a-4841-83d3-c6b1fe093e14, wedding_date=2024-12-27
# Inserting into Weddings: user_id=ef10e49b-6149-4341-8335-e16f96728fed, wedding_date=2025-08-18
# Inserting into Weddings: user_id=9b8ec470-5429-4c59-9b78-c6d7d7256ae8, wedding_date=2025-09-01
# Inserting into Weddings: user_id=c679f8b3-9aa2-44c2-942d-80e5765d44c0, wedding_date=2025-08-22
# Inserting into Weddings: user_id=6d3ee316-194b-4a0b-aefb-6367d8ef005c, wedding_date=2024-06-21
# Inserting into Weddings: user_id=ce794db8-2777-4865-b409-d6b171f43162, wedding_date=2025-01-25
# Inserting into Weddings: user_id=b730dffe-242d-4e3d-b107-4a10827100ee, wedding_date=2024-09-05
# Inserting into Weddings: user_id=b62bdde6-593f-4d2d-8320-29c343705545, wedding_date=2025-09-30
# Inserting into Weddings: user_id=abd124e9-ad07-4575-b847-aba813580e86, wedding_date=2024-06-17
# Inserting into Weddings: user_id=6b30fba9-0ed3-46e1-979f-cbb21263a653, wedding_date=2024-03-08
# Inserting into Weddings: user_id=d3d669f0-ba28-4fdb-b11c-7a4b7b28dde6, wedding_date=2024-05-06
# Inserting into Weddings: user_id=ac843fe1-87ef-42aa-a379-c4a6c8a547ce, wedding_date=2025-09-09
# Inserting into Weddings: user_id=1b66ecec-cbf3-4b8a-8c91-07fb04f53331, wedding_date=2025-11-09
# Inserting into Weddings: user_id=48fd430f-169f-4549-a1ff-f61810b2aee1, wedding_date=2025-12-25
# Inserting into Weddings: user_id=7d41d6d6-b0ef-42b7-98ac-bbeda2a4e01b, wedding_date=2024-03-26
# Inserting into Weddings: user_id=6b2e596e-9932-450f-92c5-b46f1d3a151c, wedding_date=2024-06-08
# Inserting into Weddings: user_id=cdfccb3a-1e9a-4c11-a2df-78f3db1ab509, wedding_date=2025-01-12
# Inserting into Weddings: user_id=ee4c7261-a59e-4656-a63b-767030da3017, wedding_date=2025-09-25
# Inserting into Weddings: user_id=8866ae0b-0e44-4ff7-8efb-73a2a333c578, wedding_date=2025-08-16
# Inserting into Weddings: user_id=ca735fed-49cf-4525-b448-3bdaf1db0f45, wedding_date=2025-05-31
# Inserting into Weddings: user_id=a0bc75af-8566-49e2-860e-e26656840ca1, wedding_date=2025-09-25
# Inserting into Weddings: user_id=f3441ef8-67ec-49b6-a251-914333796e49, wedding_date=2024-11-12
# Inserting into Weddings: user_id=2da092e9-d53f-45e4-afeb-b6cf785f5074, wedding_date=2025-04-01
# Inserting into Weddings: user_id=e71bcd4b-6166-4d72-9f9a-2ea9bca46fd5, wedding_date=2024-11-06
# Inserting into Weddings: user_id=564a4663-3989-4ec2-90e3-f415458562e2, wedding_date=2025-08-27
# Inserting into Weddings: user_id=ea1333bc-b598-445e-b497-ae34e7f08d98, wedding_date=2025-04-20
# Inserting into Weddings: user_id=c3ab9534-5cec-4087-883e-9e1a684334f6, wedding_date=2025-09-15
# Inserting into Weddings: user_id=6c094d08-f451-4e09-b2f7-d47719c55db2, wedding_date=2025-06-29
# Inserting into Weddings: user_id=2d5684e7-5777-4ca8-b2d6-ce86c1430651, wedding_date=2025-04-15
# Inserting into Weddings: user_id=b6d48fa8-4c7a-447a-92c3-83183322b02b, wedding_date=2025-06-01
# Inserting into Weddings: user_id=225b2c59-4b16-46c8-887e-844cad35eb03, wedding_date=2024-08-08
# Inserting into Weddings: user_id=8a975c7e-4553-4470-806a-08d819e12f7c, wedding_date=2025-07-20
# Inserting into Weddings: user_id=23747f8d-723e-4fb9-9ab0-ffa0788406bd, wedding_date=2025-07-10
# Inserting into Weddings: user_id=4e19e7d6-98c5-4bdf-a65b-54454a561e8e, wedding_date=2025-05-09
# Inserting into Weddings: user_id=147a2b22-0458-450c-b89a-bba8f380bc12, wedding_date=2024-04-09
# Inserting into Weddings: user_id=641127ff-1c57-47b0-acca-9dbbe91763f6, wedding_date=2025-02-26
# Inserting into Weddings: user_id=90c628d9-8c0b-47ae-b744-a71b0446af8e, wedding_date=2024-05-12
# Inserting into Weddings: user_id=604a24cb-6055-4661-96c5-22c5d4b0224a, wedding_date=2025-11-12
# Inserting into Weddings: user_id=066e6611-13f2-4c20-af25-890c64b95042, wedding_date=2025-05-28
# Inserting into Weddings: user_id=0c8a57f0-40c3-4dc4-9966-5c656d7b8363, wedding_date=2024-06-22
# Inserting into Weddings: user_id=0c810a97-1bea-4ffd-82d8-3a433092099a, wedding_date=2024-07-13
# Inserting into Weddings: user_id=6439b84f-2873-4e18-bb03-7b95a5398318, wedding_date=2025-09-18
# Inserting into Weddings: user_id=bfa0e361-c55d-4d3b-9e80-1552f4f0294f, wedding_date=2025-07-29
# Inserting into Weddings: user_id=3fb95b0e-748f-4335-b3c5-d41a0abf1c7e, wedding_date=2024-07-24
# Inserting into Weddings: user_id=4b779722-5d30-40b5-94a4-0d1d8111f0b5, wedding_date=2025-02-22
# Inserting into Weddings: user_id=cfd4aaba-9a1c-4b08-88d2-89c8f3293995, wedding_date=2024-10-06
# Inserting into Weddings: user_id=ea2e7447-f2b0-4911-9ff7-3c9c70459fef, wedding_date=2025-12-05
# Inserting into Weddings: user_id=019c8dcd-a16d-40c1-a7a1-9e60cd013763, wedding_date=2024-03-07
# Inserting into Weddings: user_id=3457a9e3-0eb9-4df4-af2a-10dce4ec2363, wedding_date=2025-01-01
# Inserting into Weddings: user_id=9428e9ef-6784-41eb-a92b-31cb982fdfa6, wedding_date=2024-09-18
# Inserting into Weddings: user_id=3e6cdd61-b98d-4c89-941d-a4172f0ddc95, wedding_date=2024-08-13
# Inserting into Weddings: user_id=3abd2ff5-f920-4fe4-b34b-3d63cefb6be3, wedding_date=2025-02-20
# Inserting into Weddings: user_id=baf8fbbe-14f4-4379-b2d2-724c15a792d3, wedding_date=2024-10-07
# Inserting into Weddings: user_id=dd2cc75d-1e6a-40d4-ad90-e0343236133b, wedding_date=2025-04-19
# Inserting into Weddings: user_id=27e9b19d-4f1e-48eb-b9a0-daed430f111a, wedding_date=2024-02-02
# Inserting into Weddings: user_id=628b7cc3-e797-4d53-9ee8-b1816a873a8c, wedding_date=2025-03-22
# Inserting into Weddings: user_id=726fa289-8cdf-48bf-8b08-1e92a2f0de16, wedding_date=2025-01-26
# Inserting into Weddings: user_id=ecb8d252-0adc-4e67-9133-2c9274d5547e, wedding_date=2024-02-27
# Inserting into Weddings: user_id=18085e3f-a081-4aa5-988c-b4213fb1984b, wedding_date=2025-01-03
# Inserting into Weddings: user_id=e25a71bb-1fe8-4702-b2eb-ac17c3db5c45, wedding_date=2024-10-24
# Inserting into Weddings: user_id=a61ecfc0-85ff-4b4f-a317-3a333d09d863, wedding_date=2024-12-22
# Inserting into Weddings: user_id=60ab2c22-2555-411c-be8a-78415c570689, wedding_date=2025-06-11
# Inserting into Weddings: user_id=4bdfcb78-fede-4a25-9bbe-423d199a9377, wedding_date=2025-09-13
# Inserting into Weddings: user_id=92b7d0f9-8e68-44c1-a8c1-1acb28599b07, wedding_date=2025-05-17
# Inserting into Weddings: user_id=e8c5015b-06db-4e16-bc48-a811dde62ee0, wedding_date=2025-01-10
# Inserting into Weddings: user_id=9742af7f-c77f-4ebd-b7e2-40d6e8f65f83, wedding_date=2025-02-15
# Inserting into Weddings: user_id=70b72b51-3d12-4673-8df1-96556bd38fc6, wedding_date=2025-05-08
# Inserting into Weddings: user_id=0640ac0c-ae21-4f62-886c-36d4172dd561, wedding_date=2024-10-22
# Inserting into Weddings: user_id=ac9436ae-5ddf-4f5f-8863-28310c97e463, wedding_date=2024-04-27
# Inserting into Weddings: user_id=edf172c5-29d2-44a0-8adb-21008f64d571, wedding_date=2025-08-24
# Inserting into Weddings: user_id=ef9a71e4-4e89-49c0-8e8b-e9d207a746df, wedding_date=2024-05-18
# Inserting into Weddings: user_id=b6260fcf-aeab-49f5-bc6a-3f35bf84e04c, wedding_date=2025-06-17
# Inserting into Weddings: user_id=bbacab2d-ee83-455b-b8c9-8bc05e660c9c, wedding_date=2025-01-24
# Inserting into Weddings: user_id=8a35e415-9045-4c8b-9fc3-ec698857d28f, wedding_date=2024-10-14
# Inserting into Weddings: user_id=78788bd9-4957-419c-abe3-c64bedca0740, wedding_date=2024-02-09
# Inserting into Weddings: user_id=94809e42-b880-49dc-9a26-da5d8b449acb, wedding_date=2024-08-30
# Inserting into Weddings: user_id=e75fac0b-96d6-412b-b06e-18abfc85ac30, wedding_date=2025-02-13
# Inserting into Weddings: user_id=8791463e-d128-4a06-bce5-2902ba9cc8a8, wedding_date=2024-03-21
# Inserting into Weddings: user_id=708ed8da-3e7c-4972-895b-df0a82ae03c0, wedding_date=2024-06-21
# Inserting into Weddings: user_id=48ac894f-b738-468f-b4f6-3e6378c08e38, wedding_date=2025-09-17
# Inserting into Weddings: user_id=17e7f629-cdc6-4ab5-bb20-be056f53d6a0, wedding_date=2025-04-29
# Inserting into Weddings: user_id=d43177a2-7eb1-4f3e-aa72-412205f3f67a, wedding_date=2025-01-08
# Inserting into Weddings: user_id=4e41459a-0a26-4ea6-9be9-4bc6ffff61c3, wedding_date=2024-07-31
# Inserting into Weddings: user_id=8aa33b9b-d9b6-4e5d-82cd-d158dafafdb4, wedding_date=2024-05-21
# Inserting into Weddings: user_id=879f8980-60d7-4188-bed9-422eb8663271, wedding_date=2025-02-26
# Inserting into Weddings: user_id=c6a646d2-3211-468f-abc6-dac12ad22adc, wedding_date=2025-05-24
# Inserting into Weddings: user_id=1ca873c1-b351-4c75-bf23-bd8f1515a47e, wedding_date=2025-07-04
# Inserting into Weddings: user_id=e297e8e4-2f4d-4f20-a406-cfdb8ecb5d6c, wedding_date=2024-03-25
# Inserting into Weddings: user_id=b0c7bcf9-5e87-46a2-ad8b-29216d844e33, wedding_date=2024-06-06
# Inserting into Weddings: user_id=0459e5b7-936c-447a-aad6-690072f5ecc5, wedding_date=2024-11-30

# %%
# 定义查询函数：查询 2024 年 6 月的婚礼用户
def get_weddings_in_june_2024():
    cursor.execute('''
    SELECT Users.user_name
    FROM Users
    INNER JOIN Weddings ON Users.user_id = Weddings.user_id
    WHERE strftime('%Y-%m', Weddings.wedding_date) = '2024-06'
    ''')
    results = cursor.fetchall()
    return [row[0] for row in results]

# %%
#取出第一行   cursor.fetchone()  
#取出指定数量  cursor.fetchmany()
#取出所有     cursor.fetchall()

# %%
# 保存查询结果到文件
def save_to_file(file_name, data):
    with open(file_name, 'w', encoding='utf-8') as file:
        for item in data:
            file.write(f"{item}\n")
    print(f"Saved data to {file_name}: {data}")  # 添加日志信息

# %%
# 查询 2024 年 6 月的婚礼用户并保存到文件
june_2024_weddings = get_weddings_in_june_2024()
save_to_file('june_2024_weddings.txt', june_2024_weddings)
# Out:
# Saved data to june_2024_weddings.txt: ['Grace Wilson', 'Brian Brown', 'Olivia Johnson', 'Hannah Taylor', 'David Williams', 'Daniel Thomas']

# %%
# 定义查询函数：查询两周内的婚礼用户
def get_weddings_in_2_weeks():
    today = datetime.now().date()
    two_weeks_later = today + timedelta(days=14)
    
    cursor.execute('''
    SELECT Users.user_name
    FROM Users
    INNER JOIN Weddings ON Users.user_id = Weddings.user_id
    WHERE Weddings.wedding_date BETWEEN ? AND ?
    ''', (today, two_weeks_later))
    results = cursor.fetchall()
    return [row[0] for row in results]

# %%
# 查询两周内的婚礼用户并保存到文件
two_weeks_weddings = get_weddings_in_2_weeks()
save_to_file('two_weeks_weddings.txt', two_weeks_weddings)
# Out:
# Saved data to two_weeks_weddings.txt: ['Olivia Johnson', 'Daniel Thomas']

# %%
# 关闭数据库连接
conn.close()
